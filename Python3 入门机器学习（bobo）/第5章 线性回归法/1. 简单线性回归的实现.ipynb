# %% [markdown]
# # 实现 Simple Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1., 2., 3., 4., 5.])
y = np.array([1., 3., 2., 3., 5.])

# %%
plt.scatter(x, y)
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 均值
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
num = 0.0 # 分子
d = 0.0 # 分母
for x_i, y_i in zip(x, y):
    num += (x_i - x_mean) * (y_i - y_mean)
    d += (x_i - x_mean) ** 2

# %%
a = num / d
b = y_mean - a*x_mean

# %%
print(a)
print(b)
# Out:
# 0.8
# 0.39999999999999947

# %%
# 绘制直线
y_hat = a * x + b

# %%
plt.scatter(x, y)
plt.plot(x, y_hat, color='r')
plt.axis([0, 6, 0, 6])
plt.show()

# %%
x_predict = 6.0
y_predict = a * x_predict + b

# %%
y_predict
# Out:
# 5.2

# %%
plt.scatter(x, y)
plt.scatter(x_predict, y_predict, color='b')
plt.plot(x, y_hat, color='r')
plt.axis([0, 7, 0, 7])
plt.show()

# %%
# %run SimpleLinearRegression1.py

# %%
reg1 = SimpleLinearRegression01 ()
reg1.fit(x, y)
x_predict = 6
x_predict
np.array(x_predict)
# Out:
# array(6)

# %%
reg1.predict(np.array([x_predict]))
# Out:
# array([5.2])

# %%
reg1.a_
# Out:
# 0.8

# %%
reg1.b_
# Out:
# 0.39999999999999947

# %%
y_hat1 = reg1.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, 'r')
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ## 向量化实现SImpleLinearRegression

# %%
# %run SimpleLinearRegression2.py

# %%
reg2 = SimpleLinearRegression02 ()
reg2.fit(x, y)
# Out:
# SimpleLinearRegression1()

# %%
reg2.a_
# Out:
# 0.8

# %%
reg2.b_
# Out:
# 0.39999999999999947

# %%
y_hat1 = reg1.predict(x)
plt.scatter(x, y)
plt.plot(x, y_hat1, 'r')
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ## 向量化性能测试

# %%
m = 1000000
big_x = np.random.random(size=m)
big_y = big_x * 2.0 + 3.0 + np.random.normal(size=m)

# %%
# %timeit reg1.fit(big_x, big_y)
# %timeit reg2.fit(big_x, big_y)
# Out:
# 1.4 s ± 42.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 16.2 ms ± 361 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %time 
reg1.fit(big_x, big_y)
# Out:
# Wall time: 0 ns
# SimpleLinearRegression1()

# %%
# %time 
reg2.fit(big_x, big_y)
# Out:
# Wall time: 0 ns
# SimpleLinearRegression1()

# %%
reg1.a_
# Out:
# 1.9976695813125207

# %%
reg1.b_
# Out:
# 2.999144759806248

# %%
reg2.a_
# Out:
# 1.9976695813125445

# %%
reg2.b_
# Out:
# 2.999144759806236
