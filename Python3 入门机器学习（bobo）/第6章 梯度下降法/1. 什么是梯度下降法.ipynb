# %% [markdown]
# # 1. 梯度下降法概念

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 梯度下降法的涵义

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. 超参数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
