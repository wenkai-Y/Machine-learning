# %% [markdown]
# # 数据归一化 Feature Scaling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## 数据归一化的两种方法
# ### 1.均值方差归一化（standardization）:无明显边界
# ### 2.最值归一化（normalization）:有明显边界

# %% [markdown]
# -----
# -----
# -----
# -----
# -----

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.最值归一化 Normalization

# %%
x = np.random.randint(0, 100, size=100)
x
# Out:
# array([56, 49, 93, 13, 54, 64, 51, 28, 79, 73, 89,  3, 91, 55, 31, 13, 47,
#        16, 67, 78, 57, 69, 15, 85, 59, 78, 55, 77, 78, 81, 17, 72, 13, 63,
#        67, 67, 58,  5, 31, 49, 44,  5, 69, 42, 58,  3, 69, 72, 53, 12, 48,
#        21, 62, 93, 14,  3, 74, 27, 14, 71, 87,  7,  1, 77, 57, 85, 19, 76,
#        15, 85, 35, 28,  1, 24, 83, 50, 11, 33, 24, 73, 61, 10, 53, 73,  4,
#        78, 73, 91, 63, 32, 35, 19, 90, 23, 57, 29, 91, 97, 11, 50])

# %%
(x - np.min(x))/(np.max(x)-(np.min(x)))
# Out:
# array([0.57291667, 0.5       , 0.95833333, 0.125     , 0.55208333,
#        0.65625   , 0.52083333, 0.28125   , 0.8125    , 0.75      ,
#        0.91666667, 0.02083333, 0.9375    , 0.5625    , 0.3125    ,
#        0.125     , 0.47916667, 0.15625   , 0.6875    , 0.80208333,
#        0.58333333, 0.70833333, 0.14583333, 0.875     , 0.60416667,
#        0.80208333, 0.5625    , 0.79166667, 0.80208333, 0.83333333,
#        0.16666667, 0.73958333, 0.125     , 0.64583333, 0.6875    ,
#        0.6875    , 0.59375   , 0.04166667, 0.3125    , 0.5       ,
#        0.44791667, 0.04166667, 0.70833333, 0.42708333, 0.59375   ,
#        0.02083333, 0.70833333, 0.73958333, 0.54166667, 0.11458333,
#        0.48958333, 0.20833333, 0.63541667, 0.95833333, 0.13541667,
#        0.02083333, 0.76041667, 0.27083333, 0.13541667, 0.72916667,
#        0.89583333, 0.0625    , 0.        , 0.79166667, 0.58333333,
#        0.875     , 0.1875    , 0.78125   , 0.14583333, 0.875     ,
#        0.35416667, 0.28125   , 0.        , 0.23958333, 0.85416667,
#        0.51041667, 0.10416667, 0.33333333, 0.23958333, 0.75      ,
#        0.625     , 0.09375   , 0.54166667, 0.75      , 0.03125   ,
#        0.80208333, 0.75      , 0.9375    , 0.64583333, 0.32291667,
#        0.35416667, 0.1875    , 0.92708333, 0.22916667, 0.58333333,
#        0.29166667, 0.9375    , 1.        , 0.10416667, 0.51041667])

# %%
X = np.random.randint(0, 100, (50, 2))
X
# Out:
# array([[84, 22],
#        [89,  4],
#        [63, 65],
#        [52, 26],
#        [ 7, 12],
#        [42,  0],
#        [90,  1],
#        [46,  4],
#        [56, 24],
#        [88, 22],
#        [95, 39],
#        [78, 96],
#        [31, 98],
#        [25, 78],
#        [44,  2],
#        [22, 84],
#        [46, 33],
#        [ 6, 45],
#        [76, 42],
#        [86, 57],
#        [23, 69],
#        [93, 69],
#        [21, 55],
#        [71, 86],
#        [84,  7],
#        [46, 40],
#        [17, 98],
#        [48, 49],
#        [91, 40],
#        [88, 65],
#        [25, 35],
#        [89, 40],
#        [96, 52],
#        [70, 61],
#        [45, 37],
#        [35, 73],
#        [21, 22],
#        [13, 33],
#        [ 7, 33],
#        [14, 70],
#        [84, 27],
#        [69, 62],
#        [60, 85],
#        [29, 80],
#        [67, 61],
#        [67, 55],
#        [65, 25],
#        [10, 55],
#        [90, 98],
#        [79, 36]])

# %%
X = np.array(X, dtype=float)

# %%
X[:10]
# Out:
# array([[84., 22.],
#        [89.,  4.],
#        [63., 65.],
#        [52., 26.],
#        [ 7., 12.],
#        [42.,  0.],
#        [90.,  1.],
#        [46.,  4.],
#        [56., 24.],
#        [88., 22.]])

# %%
X[:, 0] = (X[:, 0] - np.min(X[:, 0])) / (np.max(X[:, 0])-np.min(X[:, 0]))

# %%
X[:, 1] = (X[:, 1] - np.min(X[:, 1])) / (np.max(X[:, 1])-np.min(X[:, 1]))

# %%
X[:10]
# Out:
# array([[0.86666667, 0.2244898 ],
#        [0.92222222, 0.04081633],
#        [0.63333333, 0.66326531],
#        [0.51111111, 0.26530612],
#        [0.01111111, 0.12244898],
#        [0.4       , 0.        ],
#        [0.93333333, 0.01020408],
#        [0.44444444, 0.04081633],
#        [0.55555556, 0.24489796],
#        [0.91111111, 0.2244898 ]])

# %%
plt.scatter(X[:, 0], X[:, 1])

# %%
np.mean(X[:, 0])
# Out:
# 0.5428888888888889

# %%
np.std(X[:, 0])
# Out:
# 0.32063216877649847

# %%
np.mean(X[:, 1])
# Out:
# 0.4840816326530612

# %%
np.std(X[:, 1])
# Out:
# 0.2817964622692034

# %% [markdown]
# ## 2.均值方差归一化 Standardization

# %%
X2 = np.random.randint(0, 100, (50, 2))
X2[:5]
# Out:
# array([[21, 21],
#        [ 6, 19],
#        [66, 34],
#        [99, 23],
#        [60, 93]])

# %%
X2 = np.array(X2, dtype=float)

# %%
X2[:, 0] = (X2[:, 0] - np.mean(X2[:, 0])) / np.std(X2[:, 0])

# %%
X2[:, 1] = (X2[:, 1] - np.mean(X2[:, 1])) / np.std(X2[:, 1])

# %%
plt.scatter(X2[:, 0], X2[:, 1])

# %%
np.mean(X2[:, 0])
# Out:
# -2.2204460492503132e-17

# %%
np.std(X2[:, 0])
# Out:
# 0.9999999999999999

# %%
np.mean(X2[:, 1])
# Out:
# -1.208625213799941e-16

# %%
np.std(X2[:, 1])
# Out:
# 0.9999999999999999

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 对测试数据集如何归一化？

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 要保存训练数据集得到的均值和方差
# scikit-learn 中使用 Scaler

# %% [markdown]
# ![image.png](attachment:image.png)
